# %%
##importing the libraries
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing

# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

##creating out twitter app

# Consume:
CONSUMER_KEY    = 'vo4MvfhmkVn7XOwOGN68X8n6H'
CONSUMER_SECRET = 'BeT8mbt9CRfH6dWFuAYbIbzHezJ9jNSghMaPS9eEgC97rWcuZJ'

# Access:
ACCESS_TOKEN  = '3289735469-2cfN0i3v535CStJPttKGwAktJHh3EbGfJqZf1kx'
ACCESS_SECRET = 'uTlXVWsU86eKj0VpdDOnGGfBbXp3qMYVJjJDX1hjKIcYo'

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
api = tweepy.API(auth)

# %%
# from tweepy import Stream

# # Set up words to track  
# keywords_to_track = ['#election']

# # Instantiate the SListener object 
# listen = Stream

# # Instantiate the Stream object
# stream = Stream(auth, listen)

# # Begin collecting data
# stream.filter(track = keywords_to_track)

# %%
#override tweepy.StreamListener to add logic to on_status
from grpc import StatusCode
from sqlalchemy import false


class MyStreamListener(Stream):

    def on_status(self, status):
        print(status.text)
        # creating a stream
    def on_error(self, status):
        if StatusCode ==420: #end of the monthly limit 
            return false
mystream = MyStreamListener(CONSUMER_KEY,
                          CONSUMER_SECRET,
                          ACCESS_TOKEN,
                          ACCESS_SECRET)

# myStreamListener = MyStreamListener()
# myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)
# starting a stream
mystream.filter(track=['Elections'])
# Out:
# RT @AdamKinzinger: Yes because banning contraception is the new standard for true Republican . INSANE
# RT @duty2warn: Mark Finchem, who has identified himself as a member of the Oath Keepers, has won the Republican nomination for Arizona Secr…
# I’m calling absolute total BULLSHIT on the leftist media narrative that Roe v Wade and “concerns about climate chan… https://t.co/BxpyXA24Eh
# RT @912CroozeFM: Hon: Ssemujju: In 1980 I was 7 years old, I saw rebels including rebel Yoweri Museveni going to Luwero to fight saying UPC…
# RT @MZHemingway: One important way to build public confidence in elections is to have votes counted accurately within hours— not days or we…
# RT @kylegriffin1: Pennsylvania's Supreme Court has ruled to uphold the state's mail-in voting law, allowing voters to vote by mail in all f…
# RT @AdamKinzinger: Yes because banning contraception is the new standard for true Republican . INSANE
# ...
